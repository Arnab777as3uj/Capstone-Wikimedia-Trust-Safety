# %% [markdown]
# ### Creating nonblock corpus

# %%
# import necessary packages
import os
import pandas as pd
import numpy as np
import re

# set options
pd.options.display.max_colwidth = 50
pd.set_option('display.max_colwidth', -1) 
pd.options.mode.chained_assignment = None  # default='warn'
#2219

# %% [markdown]
# #### Process Blocks data

# %%
# read ipblocks
df_ipblocks = pd.read_csv("/home/ec2-user/SageMaker/bucket/wiki_trust/ipblocks_fulldump_new.csv") 
df_ipblocks = df_ipblocks.drop(df_ipblocks.columns[0],axis=1)
df_ipblocks.shape
# Out:
# (1130485, 7)

# %%
# convert object dtype to string ; keep in mind expiry with timestamp will be unusable
df_ipblocks['ipb_address'] = df_ipblocks['ipb_address'].astype('str') #ipaddress -> string
df_ipblocks['date'] = pd.to_datetime(df_ipblocks['date'], format = "%Y%m%d")

# replace NAN with empty strings
df_ipblocks.ipb_reason = df_ipblocks.ipb_reason.replace(np.nan,'', regex=True)

# %%
# clean df
df_ipblocks = df_ipblocks.drop(columns = ['ipb_id','ipb_create_account','ipb_expiry','date','ipb_reason'])
df_ipblocks.columns = ['userid','username']

# %%
df_ipblocks.head()
# Out:
#    userid             username
# 0  9418    Wanli2
# 1  17254   Xuepiao
# 2  6959    GrandVoivodOfErdely
# 3  3107    #1703
# 4  43305   Wanli3

# %% [markdown]
# #### Process XML data

# %% [markdown]
# Split Contributor into UserID and Username

# %%
df_revtxt = pd.read_csv('/home/ec2-user/SageMaker/bucket/wiki_trust/xml_dump_processed/revision_text_data_final1.txt', sep = '\t')
df_revtxt.shape
# Out:
# (1683335, 8)

# %%
#df_revtxt.head(20)
#df_revtxt.NAMESPACE.value_counts()

# split CONTRIBUTOR into userid and username  
namesplit              = df_revtxt["CONTRIBUTOR"].str.split(",", n = 1, expand = True) 
df_revtxt["USERID"]    = namesplit[0] 
df_revtxt["username"]  = namesplit[1] 

# refine columns
df_revtxt["USERID"]    = df_revtxt["USERID"].str.replace("Contributor\(id=",'')
df_revtxt["USERID"]    = df_revtxt["USERID"].str.strip()

df_revtxt["username"]  = df_revtxt["username"].str.replace("user_text='",'')
df_revtxt["username"]  = df_revtxt["username"].str[:-2]
df_revtxt["username"]  = df_revtxt["username"].str.strip()

df_revtxt.head()
# Out:
#    NAMESPACE                                    CONTRIBUTOR  \
# 0  1          Contributor(id=205121, user_text='Koavf')
# 1  1          Contributor(id=16675924, user_text='Kumioko')
# 2  1          Contributor(id=205121, user_text='Koavf')
# 3  1          Contributor(id=16675924, user_text='Kumioko')
# 4  1          Contributor(id=205121, user_text='Koavf')
#
#                                            TITLE   PAGE_ID  REVISION_ID  \
# 0  Talk:Stockdale High School (Stockdale, Texas)  35168384  483106491
# 1  Talk:Stockdale High School (Stockdale, Texas)  35168384  496151496
# 2  Talk:Stonebridge, Texas                        35168385  483106509
# 3  Talk:Stonebridge, Texas                        35168385  496151525
# 4  Talk:Stratford High School (Stratford, Texas)  35168388  483106582
#
#         TIMESTAMP  \
# 0  20120321115934
# 1  20120605183056
# 2  20120321115937
# 3  20120605183113
# 4  20120321115952
#
#                                                                            TEXT  \
# 0  {{WikiProject Texas}}
# 1  {{WikiProject United States|class=|importance=Low|TX=yes|TX-importance=Low}}
# 2  {{WikiProject Texas}}
# 3  {{WikiProject United States|class=|importance=Low|TX=yes|TX-importance=Low}}
# 4  {{WikiProject Texas}}
#
#                                                                         DIFF_TEXT  \
# 0  NaN
# 1  + {{WikiProject United States|class=|importance=Low|TX=yes|TX-importance=Low}}
# 2  NaN
# 3  + {{WikiProject United States|class=|importance=Low|TX=yes|TX-importance=Low}}
# 4  NaN
#
#      USERID username
# 0  205121    Koavf
# 1  16675924  Kumioko
# 2  205121    Koavf
# 3  16675924  Kumioko
# 4  205121    Koavf

# %%
df_merge = df_ipblocks.merge(df_revtxt, indicator=True, how='outer')
df_data = df_merge[df_merge['_merge'] == 'right_only']
df_data.shape
# Out:
# (1549082, 12)

# %%
df_data.head()
# Out:
#          userid username  NAMESPACE  \
# 1255521 NaN      Koavf    1.0
# 1255522 NaN      Koavf    1.0
# 1255523 NaN      Koavf    1.0
# 1255524 NaN      Koavf    1.0
# 1255525 NaN      Koavf    1.0
#
#                                        CONTRIBUTOR  \
# 1255521  Contributor(id=205121, user_text='Koavf')
# 1255522  Contributor(id=205121, user_text='Koavf')
# 1255523  Contributor(id=205121, user_text='Koavf')
# 1255524  Contributor(id=205121, user_text='Koavf')
# 1255525  Contributor(id=205121, user_text='Koavf')
#
#                                                  TITLE     PAGE_ID  \
# 1255521  Talk:Stockdale High School (Stockdale, Texas)  35168384.0
# 1255522  Talk:Stonebridge, Texas                        35168385.0
# 1255523  Talk:Stratford High School (Stratford, Texas)  35168388.0
# 1255524  Talk:Sulphur Springs High School               35168391.0
# 1255525  Talk:Sunray High School (Texas)                35168394.0
#
#          REVISION_ID     TIMESTAMP                   TEXT DIFF_TEXT  USERID  \
# 1255521  483106491.0  2.012032e+13  {{WikiProject Texas}}  NaN       205121
# 1255522  483106509.0  2.012032e+13  {{WikiProject Texas}}  NaN       205121
# 1255523  483106582.0  2.012032e+13  {{WikiProject Texas}}  NaN       205121
# 1255524  483106652.0  2.012032e+13  {{WikiProject Texas}}  NaN       205121
# 1255525  483106726.0  2.012032e+13  {{WikiProject Texas}}  NaN       205121
#
#              _merge
# 1255521  right_only
# 1255522  right_only
# 1255523  right_only
# 1255524  right_only
# 1255525  right_only

# %%
#df_ipblocks[df_ipblocks['username']=="Dostoyevski1881"]
# Out:
# Empty DataFrame
# Columns: [userid, username]
# Index: []

# %%
df_data['TIMESTAMP'] = df_data['TIMESTAMP'].astype('str') #timestamp -> string
df_data['TIMESTAMP'] = df_data['TIMESTAMP'].str[0:8]
df_data['TIMESTAMP'] = pd.to_datetime(df_data['TIMESTAMP'], format = "%Y%m%d")

# %%
df_data = df_data.drop(columns = ['userid','_merge','CONTRIBUTOR','PAGE_ID','REVISION_ID','TEXT'])
# check if userid doesnt match

# %%
df_data.tail()
# Out:
#                 username  namespace  \
# 2804598  Dostoyevski1881  1.0
# 2804599  Dostoyevski1881  1.0
# 2804600  Dostoyevski1881  1.0
# 2804601  Dostoyevski1881  1.0
# 2804602  95.10.67.174     1.0
#
#                                                  title revision_date  \
# 2804598  Talk:Human rights of Kurdish people in Turkey 2010-03-21
# 2804599  Talk:Human rights of Kurdish people in Turkey 2010-03-21
# 2804600  Talk:Human rights of Kurdish people in Turkey 2010-03-21
# 2804601  Talk:Human rights of Kurdish people in Turkey 2011-03-03
# 2804602  Talk:Human rights of Kurdish people in Turkey 2015-04-24
#
#                                                                                                                                                                                                                                                                 text  \
# 2804598  + I think the main purpose of the user that added this article to wikipedia is not conribution.
# 2804599  + I think the main purpose of the user that added this article to wikipedia is not contribution.
# 2804600  + I hope article will be rewritten by users that have true and completely objective information about Turkey. +    --) 20:02, 21 March 2010 (UTC)
# 2804601  NaN
# 2804602  + == language of instruction  == + Kurdish is a language of instruction in Turkey after AK Party's reforms. + --[[Special:Contributions/95. + 10. + 67. + 174|95. + 10. + 67. + 174]] ([[User talk:95. + 10. + 67. + 174|talk]]) 01:00, 24 April 2015 (UTC)
#
#            userid
# 2804598  11396525
# 2804599  11396525
# 2804600  11396525
# 2804601  11396525
# 2804602  None

# %%
df_data = df_data.rename(columns={'NAMESPACE':'namespace','TIMESTAMP':'revision_date','DIFF_TEXT':'text','USERID': 'userid','TITLE':'title'})

# %%
df_data = df_data[['userid','username','revision_date','namespace','title','text']]
df_data.head()
# Out:
#          userid username revision_date  namespace  \
# 1255521  205121  Koavf   2012-03-21     1.0
# 1255522  205121  Koavf   2012-03-21     1.0
# 1255523  205121  Koavf   2012-03-21     1.0
# 1255524  205121  Koavf   2012-03-21     1.0
# 1255525  205121  Koavf   2012-03-21     1.0
#
#                                                  title text
# 1255521  Talk:Stockdale High School (Stockdale, Texas)  NaN
# 1255522  Talk:Stonebridge, Texas                        NaN
# 1255523  Talk:Stratford High School (Stratford, Texas)  NaN
# 1255524  Talk:Sulphur Springs High School               NaN
# 1255525  Talk:Sunray High School (Texas)                NaN

# %%
df_data = df_data.sort_values(by=['username','revision_date'], ascending=True)
df_data.head(20)
# Out:
#            userid       username revision_date  namespace  \
# 2753557  126234    !!            2007-10-11     1.0
# 2753558  126234    !!            2007-10-21     3.0
# 2088812  3744755   !dea4u        2009-08-22     3.0
# 2088811  3744755   !dea4u        2009-09-25     3.0
# 2088810  3744755   !dea4u        2012-05-17     3.0
# 2088807  3744755   !dea4u        2012-10-03     3.0
# 2088809  3744755   !dea4u        2014-11-07     3.0
# 2088808  3744755   !dea4u        2014-11-13     3.0
# 2319041  16826496  !nteresting   2012-05-15     3.0
# 2724670  1848830   !paradigm!    2007-08-29     3.0
# 2666931  2836063   $trassenjunge 2006-11-23     3.0
# 2622505  2058289   $yD!          2006-12-12     3.0
# 2622506  2058289   $yD!          2006-12-12     3.0
# 2622529  2058289   $yD!          2006-12-12     1.0
# 2622510  2058289   $yD!          2006-12-13     1.0
# 2622511  2058289   $yD!          2006-12-13     1.0
# 2622512  2058289   $yD!          2006-12-13     1.0
# 2622513  2058289   $yD!          2006-12-13     1.0
# 2622514  2058289   $yD!          2006-12-14     1.0
# 2622515  2058289   $yD!          2006-12-14     1.0
#
#                                                                               title  \
# 2753557  Talk:2007 ICC World Twenty20
# 2753558  User talk:Chaser
# 2088812  User talk:Chintu rohit
# 2088811  User talk:Shshshsh
# 2088810  User talk:Boseritwik
# 2088807  User talk:Theobeseplatoon
# 2088809  User talk:195.77.232.186
# 2088808  User talk:193.235.35.30
# 2319041  User talk:!nteresting
# 2724670  User talk:66.99.52.230
# 2666931  User talk:$trassenjunge
# 2622505  User talk:The Transhumanist/Archive 2
# 2622506  User talk:The Transhumanist/Archive 2
# 2622529  Talk:List of Serial Experiments Lain media
# 2622510  Talk:International Conference to Review the Global Vision of the Holocaust
# 2622511  Talk:International Conference to Review the Global Vision of the Holocaust
# 2622512  Talk:International Conference to Review the Global Vision of the Holocaust
# 2622513  Talk:International Conference to Review the Global Vision of the Holocaust
# 2622514  Talk:International Conference to Review the Global Vision of the Holocaust
# 2622515  Talk:International Conference to Review the Global Vision of the Holocaust
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            text
# 2753557  + :See . + --  11:56, 11 October 2007 (UTC)
# 2753558  + :Thanks for implementing the update, which is the most important task. +  There are various administrative tasks (adding talk page notification templates, archiving, updating the time template) but someone usually manages to clean up if they are left out. + --  21:30, 21 October 2007 (UTC)
# 2088812  + <div style="border-style:solid; border-color:blue; background-color:AliceBlue; border-width:1px; text-align:left; padding:8px;" class="plainlinks">  + '''Chintu rohit''',  and hopefully this one has made your day better. + Spread the  by smiling at someone else, whether it be someone you have had disagreements with in the past or a good friend. + Go on, smile! Cheers, and happy editing!  <br /> <small>''Smile at others by adding {{tls|Smile}} to their talk page with a friendly message. + ''</small> + </div><!-- Template:smile -->
# 2088811  + == Good Work - Keep it up == + <div style="border-style:solid; border-color:blue; background-color:AliceBlue; border-width:1px; text-align:left; padding:8px;" class="plainlinks">  + '''Hello Shshshsh''',  <small> and hopefully this one has made your day better. + Spread the  by smiling at someone else, whether it be someone you have had disagreements with in the past or a good friend. + Go on, smile! Cheers, and happy editing!  <br /> <small>''Smile at others by adding {{tls|Smile}} to their talk page with a friendly message. + ''</small> + </div><!-- Template:smile --> + Hi bro. + I found out your great creations & work, & highly appreciate all of them , Good Work. + ( <small></small> 16:22, 25 September 2009 (UTC)).
# 2088810  + ==== + A tag has been placed on  requesting that it be speedily deleted from Wikipedia. + This has been done under  infringement. + For legal reasons, we cannot accept copyrighted images or text borrowed from other web sites or printed material, and as a consequence, your addition will most likely be deleted. + Wikipedia takes copyright violations very seriously and persistent violators '''will be '''. + If you think that the page was nominated in error, contest the nomination by clicking on the button labelled "Click here to contest this speedy deletion" in the speedy deletion tag. + Doing so will take you to the talk page where you can explain why you believe the page should not be deleted. + You can also visit '''''' to give your reasons, but be aware that once a page is tagged for speedy deletion, it may be removed without delay. + Please do not remove the speedy deletion tag yourself, but do not hesitate to add information that is consistent with . +  <!-- Template:Db-dbimgcopyvio-notice --> <!-- Template:Db-csd-notice-custom -->  <small></small> 19:38, 17 May 2012 (UTC)
# 2088807  + == October 2012 == + . + I wanted to let you know that I undid one or more of  because it didn't appear constructive. + If you think I made a mistake, or if you have any questions, you can leave me a message on . + <!-- Template:uw-vandalism1 --><!-- Template:uw-cluebotwarning1 -->    <small></small> 19:11, 3 October 2012 (UTC)
# 2088809  + ==Recent edit to == +   Thank you for your contribution to Wikipedia. + I noticed that you have posted content to the  article in a language other than English. + When on the English-language Wikipedia, please always use English. + Thank you! <small></small> 10:13, 7 November 2014 (UTC)
# 2088808  + == November 2014 == + . + I wanted to let you know that I undid one or more of [[Special:Contributions/193. + 235. + 35. + 30|your recent contributions]]&nbsp;to  because it did not appear constructive. + If you would like to experiment, please use the . + If you think I made a mistake, or if you have any questions, you can leave me a message on . + <!-- Template:uw-vandalism1 -->  <small></small> 10:32, 13 November 2014 (UTC) + :''If this is a  for yourself so you can avoid further irrelevant notices. + ''<!-- Template:Shared IP advice -->
# 2319041  NaN
# 2724670  + <div style="padding:5px; border:1px solid #c0c090; background-color:#FEC;" class="user-block"> }}. + Once the block has expired, you are welcome to make constructive contributions. +  If you believe this block is unjustified, you may  by adding the text <!-- Copy the text as it appears on your page, not as it appears in this edit area. + Do not include the "nowiki" tags. + --><nowiki>{{</nowiki>unblock|''your reason here''<nowiki>}}</nowiki><!-- Do not include the "nowiki" tags. + --> below. + {{{{{subst|}}}#if:{{{sig|}}}| 18:57, 29 August 2007 (UTC) <br clear="both">
# 2666931  NaN
# 2622505  + == Need help with copyediting == + Hi Transhumanist! I am currently trying to get  through FAC, and not being a native english speaker, I am in need of help with the text quality. + I turn to you as one of the most experienced contributors I encountered: would you have a minute to spare to give it a look? And if not, maybe you know someone who would? Thanks for reading. + -- 10:44, 12 December 2006 (UTC)
# 2622506  + ::Thanks a lot, that's appreciated. + What do you mean about message boxes?-- 12:49, 12 December 2006 (UTC)
# 2622529  NaN
# 2622510  + == Public Opinion in Iran == + This section is a bit POV'd to me. + To go to the extent of quoting "a student" against the conference, and ''nothing'' in its favor (there must be someone in Iran, if not most of the population, that supports the move) seems a bit. + . + .extreme. + -- 13:47, 13 December 2006 (UTC)
# 2622511  + **Neither do I, and it bugs me a lot. + I'm pretty sure if I me and my browser were arabic-friendly it'd be easier. + -- 15:10, 13 December 2006 (UTC)
# 2622512  + :Well, some of them ''are'' total deniers, but very few indeed. + Most of them deny a ''part'' of the official holocaust theory (some the gas chambers, some the figures, some the methods, etc) but the general persecution-deportation scheme is clearly accepted by most. + Then, you have to consider that they've been imprisoned for something that is a crime in their country, and any comment on that should be made in . + == Attendees ==  + Shouldn't it be mentioned that several rabbis participate?-- 16:14, 13 December 2006 (UTC)
# 2622513  + ****Well, I can't be sure about Wikipedia, but you sure are! ;)-- 16:40, 13 December 2006 (UTC) + **Actually, it's not. + It says one rabbi in the lead,and then some jewish associations. + -- 16:40, 13 December 2006 (UTC)
# 2622514  + ::Completely off-topic. + The discussion is about laws & regulations in the UE, not this conference. + Please take it to  if you wish to continue it. + -- 11:33, 14 December 2006 (UTC)
# 2622515  + :::Thanks a lot . + I hate these situations where "antisemit" hangs in the air like a Damocles sword. + -- 15:59, 14 December 2006 (UTC)

# %%
df_user = pd.DataFrame(df_data['username'].unique())
df_user.columns = ['username']
df_user.head()
# Out:
#         username
# 0  !!
# 1  !dea4u
# 2  !nteresting
# 3  !paradigm!
# 4  $trassenjunge

# %%
userlist = np.array(df_user['username'].sample(n=30000, random_state=1))

# %%
userlist
# Out:
# array(['GlobalTruthiness', '122.106.204.247', '69.205.53.187', ...,
#        '75.179.153.110', '24.97.81.253', 'Dragonfiend'], dtype=object)

# %%
df_data2 = df_data.loc[df_data['username'].isin(userlist)]
df_data2.shape
# Out:
# (411596, 6)

# %%
df_data2['username'].nunique()
# Out:
# 30000

# %%
df_data2.head(10)
# Out:
#            userid              username revision_date  namespace  \
# 2088812  3744755   !dea4u               2009-08-22     3.0
# 2088811  3744755   !dea4u               2009-09-25     3.0
# 2088810  3744755   !dea4u               2012-05-17     3.0
# 2088807  3744755   !dea4u               2012-10-03     3.0
# 2088809  3744755   !dea4u               2014-11-07     3.0
# 2088808  3744755   !dea4u               2014-11-13     3.0
# 2666931  2836063   $trassenjunge        2006-11-23     3.0
# 2641224  27644245  (1)AnotherNewAccount 2016-04-11     1.0
# 2641225  27644245  (1)AnotherNewAccount 2016-04-11     1.0
# 2298120  15033274  (CA)Giacobbe         2012-05-11     1.0
#
#                                             title  \
# 2088812  User talk:Chintu rohit
# 2088811  User talk:Shshshsh
# 2088810  User talk:Boseritwik
# 2088807  User talk:Theobeseplatoon
# 2088809  User talk:195.77.232.186
# 2088808  User talk:193.235.35.30
# 2666931  User talk:$trassenjunge
# 2641224  Talk:Ostend–Bruges International Airport
# 2641225  Talk:Ostend–Bruges International Airport
# 2298120  Talk:Wide Awake (song)
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            text
# 2088812  + <div style="border-style:solid; border-color:blue; background-color:AliceBlue; border-width:1px; text-align:left; padding:8px;" class="plainlinks">  + '''Chintu rohit''',  and hopefully this one has made your day better. + Spread the  by smiling at someone else, whether it be someone you have had disagreements with in the past or a good friend. + Go on, smile! Cheers, and happy editing!  <br /> <small>''Smile at others by adding {{tls|Smile}} to their talk page with a friendly message. + ''</small> + </div><!-- Template:smile -->
# 2088811  + == Good Work - Keep it up == + <div style="border-style:solid; border-color:blue; background-color:AliceBlue; border-width:1px; text-align:left; padding:8px;" class="plainlinks">  + '''Hello Shshshsh''',  <small> and hopefully this one has made your day better. + Spread the  by smiling at someone else, whether it be someone you have had disagreements with in the past or a good friend. + Go on, smile! Cheers, and happy editing!  <br /> <small>''Smile at others by adding {{tls|Smile}} to their talk page with a friendly message. + ''</small> + </div><!-- Template:smile --> + Hi bro. + I found out your great creations & work, & highly appreciate all of them , Good Work. + ( <small></small> 16:22, 25 September 2009 (UTC)).
# 2088810  + ==== + A tag has been placed on  requesting that it be speedily deleted from Wikipedia. + This has been done under  infringement. + For legal reasons, we cannot accept copyrighted images or text borrowed from other web sites or printed material, and as a consequence, your addition will most likely be deleted. + Wikipedia takes copyright violations very seriously and persistent violators '''will be '''. + If you think that the page was nominated in error, contest the nomination by clicking on the button labelled "Click here to contest this speedy deletion" in the speedy deletion tag. + Doing so will take you to the talk page where you can explain why you believe the page should not be deleted. + You can also visit '''''' to give your reasons, but be aware that once a page is tagged for speedy deletion, it may be removed without delay. + Please do not remove the speedy deletion tag yourself, but do not hesitate to add information that is consistent with . +  <!-- Template:Db-dbimgcopyvio-notice --> <!-- Template:Db-csd-notice-custom -->  <small></small> 19:38, 17 May 2012 (UTC)
# 2088807  + == October 2012 == + . + I wanted to let you know that I undid one or more of  because it didn't appear constructive. + If you think I made a mistake, or if you have any questions, you can leave me a message on . + <!-- Template:uw-vandalism1 --><!-- Template:uw-cluebotwarning1 -->    <small></small> 19:11, 3 October 2012 (UTC)
# 2088809  + ==Recent edit to == +   Thank you for your contribution to Wikipedia. + I noticed that you have posted content to the  article in a language other than English. + When on the English-language Wikipedia, please always use English. + Thank you! <small></small> 10:13, 7 November 2014 (UTC)
# 2088808  + == November 2014 == + . + I wanted to let you know that I undid one or more of [[Special:Contributions/193. + 235. + 35. + 30|your recent contributions]]&nbsp;to  because it did not appear constructive. + If you would like to experiment, please use the . + If you think I made a mistake, or if you have any questions, you can leave me a message on . + <!-- Template:uw-vandalism1 -->  <small></small> 10:32, 13 November 2014 (UTC) + :''If this is a  for yourself so you can avoid further irrelevant notices. + ''<!-- Template:Shared IP advice -->
# 2666931  NaN
# 2641224  + {{WPAVIATION|Airports-project=yes|class=C + | b1 <!--Referencing & citations--> = no + | b2 <!--Coverage & accuracy    --> = no + | b3 <!--Structure              --> = yes + | b4 <!--Grammar & style        --> = yes + | b5 <!--Supporting materials   --> = yes + }} + {{WPBelgium|class=Start|importance=Low}}
# 2641225  + {{sourcecheck|checked=true}}
# 2298120  NaN

# %%
# dump final dataframe to csv
header = ['userid','username','revision_date','namespace','title','text']
df_data2.to_csv('/home/ec2-user/SageMaker/bucket/wiki_trust/xml_dump_processed/nonblockcorpus1.txt', sep = '\t',encoding='utf-8',header = True,index=False)
